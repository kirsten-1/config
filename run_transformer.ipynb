# %% [markdown]
# <a href="https://colab.research.google.com/github/kirsten-1/config/blob/main/run_transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
path="/content/drive/MyDrive/Colab Notebooks/transformer-with-pytorch"
os.chdir(path)
os.listdir(path)
# Out:
# ['model.py',
#  'config.py',
#  'dataset.py',
#  'tokenizer_en.json',
#  'tokenizer_it.json',
#  'train.py',
#  '.DS_Store',
#  '.idea',
#  '__pycache__',
#  'opus_books_weights',
#  'runs']

# %%
# !python train.py
# Out:
# {'batch_size': 8, 'num_epochs': 20, 'lr': 0.0001, 'seq_len': 350, 'd_model': 512, 'datasource': 'opus_books', 'lang_src': 'en', 'lang_tgt': 'it', 'model_folder': 'weights', 'model_basename': 'tmodel_', 'tokenizer_file': 'tokenizer_{0}.json', 'experiment_name': 'runs/tmodel'}
# Using device cpu
# README.md: 28.1kB [00:00, 121MB/s]
# en-it/train-00000-of-00001.parquet: 100% 5.73M/5.73M [00:00<00:00, 7.52MB/s]
# Generating train split: 100% 32332/32332 [00:00<00:00, 1042065.51 examples/s]
# Max length of source sentence: 316
# Max length of target sentence: 287
# Processing epoch 00:  20% 729/3638 [1:48:25<7:18:14,  9.04s/it, loss=6.957]

# %%
# !pip install tensorboard datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.9/193.9 kB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 69.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.6/221.6 kB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.3/377.3 kB 34.2 MB/s eta 0:00:00
# ...
